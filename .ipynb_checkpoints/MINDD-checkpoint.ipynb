# %%
import pandas as pd
df = pd.read_csv("hotel_booking.csv")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# 2. Get all information about the dataframe, such as the number of rows, number of columns, column
# names and their types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# 3. View only the variable names in this dataframe.

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# 4. What is the size of the data set?

# %%
df.size
# Out:
# 4122

# %% [markdown]
# 5. Get statistics from the dataframe's numerical columns

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# 6. Get information about categorical columns

# %%
#df.select_dtypes(include=['object']).columns.tolist()
df.describe(include=['object'])
# Out:
#                  Name                  Team Position Height   College
# count             457                   457      457    457       373
# unique            457                    30        5     18       118
# top     Avery Bradley  New Orleans Pelicans       SG    6-9  Kentucky
# freq                1                    19      102     59        22

# %% [markdown]
# 7. View the first rows of the dataframe and then the last rows.

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# 8. Select the College column

# %%
df[["College"]]
# Out:
#                College
# 0                Texas
# 1            Marquette
# 2    Boston University
# 3        Georgia State
# 4                  NaN
# ..                 ...
# 453             Butler
# 454                NaN
# 455                NaN
# 456             Kansas
# 457                NaN
#
# [458 rows x 1 columns]

# %% [markdown]
# 9. Select columns Name, Position, College, and rows 15 to 20

# %%
df[["College", "Position", "College"]].loc[15:20]
# Out:
#            College Position         College
# 15             NaN       SG             NaN
# 16  Oklahoma State       SG  Oklahoma State
# 17  North Carolina       SG  North Carolina
# 18         Arizona       SG         Arizona
# 19    Georgia Tech       PG    Georgia Tech
# 20             NaN       SG             NaN

# %% [markdown]
# 10. View all players from Position ‘PF’

# %%
df.loc[df["Position"] == "PF"]
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 4       Jonas Jerebko          Boston Celtics     8.0       PF  29.0   6-10
# 5        Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 6       Jordan Mickey          Boston Celtics    55.0       PF  21.0    6-8
# 24   Chris McCullough           Brooklyn Nets     1.0       PF  21.0   6-11
# 25        Willie Reed           Brooklyn Nets    33.0       PF  26.0   6-10
# ..                ...                     ...     ...      ...   ...    ...
# 435    Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0    7-1
# 441       Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 442     Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# 446    Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 452        Trey Lyles               Utah Jazz    41.0       PF  20.0   6-10
#
#      Weight       College      Salary
# ...

# %% [markdown]
# 11. View the players from Team = Orlando Magic (all columns except Team)

# %%
df.loc[df["Team"] == "Orlando Magic", df.columns != 'Team']
#nba_data.loc[nba_data["Team"] == "Orlando Magic"].drop("Team", axis=1)
# Out:
#                  Name  Number Position   Age Height  Weight  \
# 354    Dewayne Dedmon     3.0        C  26.0    7-0   245.0
# 355     Evan Fournier    10.0       SG  23.0    6-7   205.0
# 356      Aaron Gordon     0.0       PF  20.0    6-9   220.0
# 357     Mario Hezonja    23.0       SG  21.0    6-8   218.0
# 358    Ersan Ilyasova     7.0       PF  29.0   6-10   235.0
# 359  Brandon Jennings    55.0       PG  26.0    6-1   169.0
# 360      Devyn Marble    11.0       SF  23.0    6-6   200.0
# 361    Shabazz Napier    13.0       PG  24.0    6-1   175.0
# 362  Andrew Nicholson    44.0       PF  26.0    6-9   250.0
# 363    Victor Oladipo     5.0       SG  24.0    6-4   210.0
# 364     Elfrid Payton     4.0       PG  22.0    6-4   185.0
# 365       Jason Smith    14.0       PF  30.0    7-0   240.0
# 366    Nikola Vucevic     9.0        C  25.0    7-0   260.0
# 367       C.J. Watson    32.0       PG  32.0    6-2   175.0
#
#                  College      Salary
# ...

# %% [markdown]
# 12. Count number of Nas per column

# %%
df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %% [markdown]
# 13. Remove the line with all columns: NaN

# %%
df.dropna()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %% [markdown]
# 14. Fill in College column NaN values with 'no College'

# %%
df["College"].fillna("no College", inplace=True)
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3112\3775558073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["College"].fillna("no College", inplace=True)
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# ...

# %% [markdown]
# 15. View the lines with Salary NaN

# %%
df[df['Salary'].isna()]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %% [markdown]
# 16. Fill in the NaN salary values with the average salary value of the respective Team/Position

# %%
df["Salary"].fillna(df.groupby(['Team', 'Position'])['Salary'].transform('mean'))
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# 17. View the lines of dataframe with the salary values filled

# %%
df[df['Salary'].notna()]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %% [markdown]
# 18. Count the number of Nas throughout all the dataframe

# %%
df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College      0
# Salary      12
# dtype: int64

# %% [markdown]
# 19. Get the number of Teams and visualize their names

# %%
df['Team'].nunique() #Number of unique teams
# Out:
# 30

# %% [markdown]
# 20. Get the number of players by Team

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# 21. Get the number of players by Position

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %% [markdown]
# 22. Make a contingency table with the number of players by Team and Position

# %%
pd.crosstab(df['Team'], df['Position'])
# Out:
# Position                C  PF  PG  SF  SG
# Team
# Atlanta Hawks           3   4   2   2   4
# Boston Celtics          3   3   4   1   4
# Brooklyn Nets           2   4   3   0   6
# Charlotte Hornets       3   3   3   1   5
# Chicago Bulls           2   5   2   2   4
# Cleveland Cavaliers     3   2   3   2   5
# Dallas Mavericks        3   4   4   2   2
# Denver Nuggets          3   2   3   3   4
# Detroit Pistons         3   2   4   4   2
# Golden State Warriors   3   2   2   5   3
# Houston Rockets         2   4   2   3   4
# Indiana Pacers          2   4   4   3   2
# Los Angeles Clippers    2   3   3   4   3
# Los Angeles Lakers      3   4   3   4   1
# Memphis Grizzlies       1   6   5   3   3
# Miami Heat              1   4   2   5   3
# Milwaukee Bucks         2   3   4   3   4
# Minnesota Timberwolves  3   4   3   3   1
# New Orleans Pelicans    3   3   4   4   5
# New York Knicks         2   4   2   4   4
# Oklahoma City Thunder   3   3   2   3   4
# ...

# %% [markdown]
# 23. What is the average age of NBA players? Make an Age boxplot

# %%
import matplotlib.pyplot as plt
average_age = df['Age'].mean()
df.boxplot(column='Age', grid=False)
plt.title('Boxplot of NBA Player Ages')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# 24. What is the distribution of player ages in the NBA? Plot an Age histogram

# %%
df['Age'].plot(kind='hist', bins=10, color='skyblue', edgecolor='black')

# %% [markdown]
# 25. Make a Salary vs. Age vs. Position plot

# %%
for position in df['Position'].unique():
    subset = df[df['Position'] == position]
    plt.scatter(subset['Age'], subset['Salary'], label=position, s=100, alpha=0.7)
plt.title('Salary vs. Age vs. Position of NBA Players')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.legend(title='Position')
plt.grid()
plt.show()

# %% [markdown]
# 26. View the data in alphabetical order by College and decreasing Age

# %%
##df.sort_values(by=['College', 'Age'], ascending=[True, False])

# %% [markdown]
# 27. Get the statistics of the Age variable grouped by Position

# %%
df.groupby('Position')['Age'].describe()

# %% [markdown]
# 28. Make a boxplot of Age players vs. Position

# %%
df.boxplot(column='Age', by='Position', grid=False)
plt.xlabel('Position')
plt.ylabel('Age')

# %% [markdown]
# 29. Who are the top 10 highest-paid NBA players?

# %%
df.nlargest(10, 'Salary')

# %% [markdown]
# 30. What is the distribution of player salaries in the NBA? Plot a histogram

# %%
df['Salary'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of NBA Player Salaries')
plt.xlabel('Salary')
plt.ylabel('Number of Players')

# %% [markdown]
# 31. View the mean Age and mean Salary of the players

# %%
mean_age = df['Age'].mean()
mean_salary =df['Salary'].mean()
mean_age,mean_salary

# %% [markdown]
# 32. Present players for whom the age is lower than average and the salary is higher than average, order by
# Age and Salary

# %%
df[(df['Age'] < mean_age) & (df['Salary'] > mean_salary)].sort_values(by=['Age', 'Salary'])

# %% [markdown]
# 33. Who are the top three teams with the highest average salary?

# %%
df.groupby('Team')['Salary'].mean().nlargest(3)

# %% [markdown]
# 34. Which player has the highest salary on each team?

# %%
df.loc[df.groupby('Team')['Salary'].idxmax()][['Team', 'Name', 'Salary']]

# %% [markdown]
# 35. Get the Salary statistics per Position. Which position has the highest average salary

# %%
salary_stats_per_position = df.groupby('Position')['Salary'].describe()
highest_avg_salary_position = df.groupby('Position')['Salary'].mean().idxmax()

salary_stats_per_position, highest_avg_salary_position

# %% [markdown]
# 36. Make a boxplot of Salary vs. Position

# %%
df.boxplot(column='Salary', by='Position', grid=False)
plt.xlabel('Position')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# 37. Are there any outliers in terms of player salaries, and if so, who are they?

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1

# Define thresholds for identifying outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['Salary'] < lower_bound) | (df['Salary'] > upper_bound)][['Name', 'Team', 'Salary']]

outliers
# Out:
#                   Name                   Team      Salary
# 23         Brook Lopez          Brooklyn Nets  19689000.0
# 33     Carmelo Anthony        New York Knicks  22875000.0
# 89       Klay Thompson  Golden State Warriors  15501000.0
# 96       Blake Griffin   Los Angeles Clippers  18907726.0
# 98      DeAndre Jordan   Los Angeles Clippers  19689000.0
# 100         Chris Paul   Los Angeles Clippers  21468695.0
# 109        Kobe Bryant     Los Angeles Lakers  25000000.0
# 111        Roy Hibbert     Los Angeles Lakers  15592217.0
# 143   DeMarcus Cousins       Sacramento Kings  15851950.0
# 153       Jimmy Butler          Chicago Bulls  16407500.0
# 164       Derrick Rose          Chicago Bulls  20093064.0
# 168       Kyrie Irving    Cleveland Cavaliers  16407501.0
# 169       LeBron James    Cleveland Cavaliers  22970500.0
# 174         Kevin Love    Cleveland Cavaliers  19689000.0
# 189      Tobias Harris        Detroit Pistons  16000000.0
# ...

# %% [markdown]
# 38. Get the number of players in each Position by Height

# %%
players_count = df.groupby(['Position', 'Height']).size().reset_index(name='Number of Players')
players_count
# Out:
#    Position Height  Number of Players
# 0         C   6-10                 12
# 1         C   6-11                 22
# 2         C    6-8                  2
# 3         C    6-9                  7
# 4         C    7-0                 24
# 5         C    7-1                  5
# 6         C    7-2                  3
# 7         C    7-3                  3
# 8        PF   6-10                 31
# 9        PF   6-11                 17
# 10       PF    6-7                  1
# 11       PF    6-8                 15
# 12       PF    6-9                 30
# 13       PF    7-0                  3
# 14       PF    7-1                  2
# 15       PF    7-3                  1
# 16       PG   5-11                  3
# 17       PG    5-9                  1
# 18       PG    6-0                 10
# 19       PG    6-1                 15
# 20       PG    6-2                 13
# 21       PG    6-3                 29
# 22       PG    6-4                  9
# 23       PG    6-5                  7
# ...

# %% [markdown]
# 39. Make a plot of the number of players in each Position by Height

# %%
plt.figure(figsize=(12, 6))
for position in players_count['Position'].unique():
    subset = players_count[players_count['Position'] == position]
    plt.scatter(subset['Height'], subset['Number of Players'], label=position, s=100, alpha=0.7)

plt.title('Number of Players by Position and Height')
plt.xlabel('Height')
plt.ylabel('Number of Players')
plt.legend(title='Position')
plt.grid()
plt.show()

# %% [markdown]
# 40. Is there a correlation between a player's height and their salary?

# %%
def height_to_inches(height):
    if pd.isnull(height):
        return None
    feet, inches = map(int, height.split('-'))
    return feet * 12 + inches

# Aplicar a conversão
df['Height_in_inches'] = df['Height'].apply(height_to_inches)

# Calcular a correlação entre altura e salário
correlation = df['Height_in_inches'].corr(df['Salary'])

correlation
# Out:
# 0.05879192990924271
